# %%
# !git clone https://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@github.com/bouchrabenkhelifa/counterfactual-forecasting-rl
# Out:
# Cloning into 'counterfactual-forecasting-rl'...
# remote: Enumerating objects: 625, done.
# remote: Counting objects: 100% (248/248), done.
# remote: Compressing objects: 100% (189/189), done.
# remote: Total 625 (delta 111), reused 150 (delta 41), pack-reused 377 (from 1)
# Receiving objects: 100% (625/625), 60.78 MiB | 28.25 MiB/s, done.
# Resolving deltas: 100% (230/230), done.

# %%
cd counterfactual-forecasting-rl
# Out:
# [Errno 2] No such file or directory: 'counterfactual-forecasting-rl'
# /content/counterfactual-forecasting-rl/counterfactual-forecasting-rl/counterfactual-forecasting-rl/counterfactual-forecasting-rl/counterfactual-forecasting-rl/counterfactual-forecasting-rl

# %%
# !pip install -q torch pandas numpy scikit-learn matplotlib
# !pip install -q reformer_pytorch einops

# %% [markdown]
# #RL val prox

# %%
# !python -m scripts.train_val_prox
# Out:
# ...
# RL Counterfactual Training
# Pipeline : Validity + Proximity
# ...
# Device : cuda:0
#
# [RL] Loading frozen models ...
# [AE] Loaded from assets/checkpoints/ae/ae_etth1.pt
#   val_loss   = 0.007065705635911928
#   seq_len    = 96
#   hidden_dim = 64
#   latent_dim = 64
#   n_blocks   = 6
#   RF         = 127/96 ✓
# [Forecaster] Loaded ✓  seq=96  pred=48
# train 8497
# test 2833
# [Data] Scaler loaded from AE checkpoint ✓
# [RL] Objectif : réduire mean(forecast) de 10%
# [RL] Actor 134,400  Critic 51,713
#
# ...
# RL Training | 50 epochs | rho=0.1 | eta=0.15
# ...
# Epoch 001/50 | R=0.9665 | val=0.523 | Δ=0.1455 | SR=52.9% | prox=0.886 | 8.0s
#   ✅ best = 0.9665
# Epoch 002/50 | R=1.1529 | val=0.718 | Δ=0.2541 | SR=84.4% | prox=0.869 | 6.6s
#   ✅ best = 1.1529
# Epoch 003/50 | R=1.1983 | val=0.767 | Δ=0.2893 | SR=88.9% | prox=0.863 | 5.8s
#   ✅ best = 1.1983
# Epoch 004/50 | R=1.2231 | val=0.794 | Δ=0.3104 | SR=92.9% | prox=0.858 | 6.4s
#   ✅ best = 1.2231
# ...

# %%
from google.colab import files
import os

for fig in os.listdir("figures/rl_valid_prox/"):
    files.download(f"figures/rl_valid_prox/{fig}")
    print(f"✅ {fig}")
# Out:
# ✅ rl_cf_examples_S.png
# ✅ rl_training_curves_S.png

# %% [markdown]
# #latent plausibility

# %% [markdown]
# eta=0.15 et 50 epochs

# %%
# !python -m scripts.latent_train15
# Out:
# Device   : cuda:0
# Pipeline : Latent Space + LatentPlausibility (différentiable)
#
# [RL-Latent] Loading frozen models ...
# [AE] Loaded from assets/checkpoints/ae/ae_etth1.pt
#   val_loss   = 0.007065705635911928
#   seq_len    = 96
#   hidden_dim = 64
#   latent_dim = 64
#   n_blocks   = 6
#   RF         = 127/96 ✓
# [Forecaster] Loaded ✓  seq=96  pred=48
# [RL-Latent] LatentPlausibility loaded ✓
# train 8497
# test 2833
# [Data] Scaler loaded ✓
# [RL-Latent] Objectif : réduire mean(forecast) de 10%
# [RL-Latent] gamma = 0.3 (plausibilité différentiable)
# [RL-Latent] Actor 134,400  Critic 51,713
#
# ...
# RL-Latent Training | 50 epochs | rho=0.1 | eta=0.15
# ...
# Epoch 001/50 | R=1.1790 | val=0.572 | Δ=0.1708 | SR=60.9% | prox=0.884 | plaus=0.550 | 10.4s
#   ✅ best = 1.1790
# Epoch 002/50 | R=1.3431 | val=0.744 | Δ=0.2716 | SR=86.7% | prox=0.868 | plaus=0.550 | 9.6s
#   ✅ best = 1.3431
# Epoch 003/50 | R=1.3834 | val=0.789 | Δ=0.3061 | SR=91.6% | prox=0.858 | plaus=0.549 | 9.7s
# ...

# %%
from google.colab import files
import os

for fig in os.listdir("figures/rl_latent_plaus/"):
    files.download(f"figures/rl_latent_plaus/{fig}")
    print(f"✅ {fig}")
# Out:
# ✅ rl_lp_training_curves.png
# ✅ rl_lp_cf_examples.png

# %% [markdown]
# eta=0.0251 et 30 epochs

# %%
# !python -m scripts.latent_train
# Out:
# Device   : cuda:0
# Pipeline : Latent Space + LatentPlausibility (différentiable)
#
# [RL-Latent] Loading frozen models ...
# [AE] Loaded from assets/checkpoints/ae/ae_etth1.pt
#   val_loss   = 0.007065705635911928
#   seq_len    = 96
#   hidden_dim = 64
#   latent_dim = 64
#   n_blocks   = 6
#   RF         = 127/96 ✓
# [Forecaster] Loaded ✓  seq=96  pred=48
# [RL-Latent] LatentPlausibility loaded ✓
# train 8497
# test 2833
# [Data] Scaler loaded ✓
# [RL-Latent] Objectif : réduire mean(forecast) de 10%
# [RL-Latent] gamma = 0.3 (plausibilité différentiable)
# [RL-Latent] Actor 134,400  Critic 51,713
#
# ...
# RL-Latent Training | 30 epochs | rho=0.1 | eta=0.0251
# ...
# Epoch 001/30 | R=0.9020 | val=0.273 | Δ=0.0219 | SR=4.5% | prox=0.928 | plaus=0.551 | 13.2s
#   ✅ best = 0.9020
# Epoch 002/30 | R=0.9246 | val=0.296 | Δ=0.0337 | SR=7.7% | prox=0.927 | plaus=0.552 | 12.2s
#   ✅ best = 0.9246
# Epoch 003/30 | R=0.9397 | val=0.311 | Δ=0.0421 | SR=9.9% | prox=0.926 | plaus=0.552 | 12.7s
# ...

# %% [markdown]
# eta=0.1

# %%
# !python -m scripts.latent_train
# Out:
# Device   : cuda:0
# Pipeline : Latent Space + LatentPlausibility (différentiable)
#
# [RL-Latent] Loading frozen models ...
# [AE] Loaded from assets/checkpoints/ae/ae_etth1.pt
#   val_loss   = 0.007065705635911928
#   seq_len    = 96
#   hidden_dim = 64
#   latent_dim = 64
#   n_blocks   = 6
#   RF         = 127/96 ✓
# [Forecaster] Loaded ✓  seq=96  pred=48
# [RL-Latent] LatentPlausibility loaded ✓
# train 8497
# test 2833
# [Data] Scaler loaded ✓
# [RL-Latent] Objectif : réduire mean(forecast) de 10%
# [RL-Latent] gamma = 0.3 (plausibilité différentiable)
# [RL-Latent] Actor 134,400  Critic 51,713
#
# ...
# RL-Latent Training | 30 epochs | rho=0.1 | eta=0.1
# ...
# Epoch 001/30 | R=1.0276 | val=0.409 | Δ=0.0851 | SR=32.3% | prox=0.907 | plaus=0.552 | 12.6s
#   ✅ best = 1.0276
# Epoch 002/30 | R=1.1791 | val=0.565 | Δ=0.1616 | SR=63.3% | prox=0.897 | plaus=0.553 | 12.2s
#   ✅ best = 1.1791
# Epoch 003/30 | R=1.2323 | val=0.620 | Δ=0.1908 | SR=72.7% | prox=0.892 | plaus=0.552 | 11.6s
# ...

# %% [markdown]
# eta=0.15

# %%
# !python -m scripts.latent_train
# Out:
# Device   : cuda:0
# Pipeline : Latent Space + LatentPlausibility (différentiable)
#
# [RL-Latent] Loading frozen models ...
# [AE] Loaded from assets/checkpoints/ae/ae_etth1.pt
#   val_loss   = 0.007065705635911928
#   seq_len    = 96
#   hidden_dim = 64
#   latent_dim = 64
#   n_blocks   = 6
#   RF         = 127/96 ✓
# [Forecaster] Loaded ✓  seq=96  pred=48
# [RL-Latent] LatentPlausibility loaded ✓
# train 8497
# test 2833
# [Data] Scaler loaded ✓
# [RL-Latent] Objectif : réduire mean(forecast) de 10%
# [RL-Latent] gamma = 0.3 (plausibilité différentiable)
# [RL-Latent] Actor 134,400  Critic 51,713
#
# ...
# RL-Latent Training | 30 epochs | rho=0.1 | eta=0.15
# ...
# Epoch 001/30 | R=1.1199 | val=0.511 | Δ=0.1387 | SR=50.4% | prox=0.888 | plaus=0.549 | 14.2s
#   ✅ best = 1.1199
# Epoch 002/30 | R=1.3342 | val=0.734 | Δ=0.2647 | SR=86.4% | prox=0.871 | plaus=0.549 | 12.4s
#   ✅ best = 1.3342
# Epoch 003/30 | R=1.3775 | val=0.781 | Δ=0.2975 | SR=91.7% | prox=0.865 | plaus=0.549 | 12.0s
# ...

# %% [markdown]
# #RL val prox plaus

# %%
# !python -m scripts.RL2
# Out:
# Device : cuda:0
#
# [RL] Loading frozen models ...
# [AE] Loaded from assets/checkpoints/ae/ae_etth1.pt
#   val_loss   = 0.007065705635911928
#   seq_len    = 96
#   hidden_dim = 64
#   latent_dim = 64
#   n_blocks   = 6
#   RF         = 127/96 ✓
# [Forecaster] Loaded ✓  seq=96  pred=48
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator ExtraTreeRegressor from version 1.8.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator IsolationForest from version 1.8.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# ...

# %% [markdown]
# #RL without AE

# %%
# !python -m scripts.RL_without_ae
# Out:
# Device    : cuda:0
# Pipeline  : Input Space (sans AE)
# Objectif  : réduire mean(forecast) de 10%
# eta_input : 0.2
#
# [RL-Input] Loading frozen models ...
# [Forecaster] Loaded ✓  seq=96  pred=48
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator ExtraTreeRegressor from version 1.8.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator IsolationForest from version 1.8.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
# ...

# %%
from google.colab import files
import os

# Checkpoints
files.download("assets/checkpoints/rl_input_space/rl_input_agent_best.pt")
files.download("assets/checkpoints/rl_input_space/rl_input_agent_final.pt")

# History
files.download("assets/results/rl_input_space/rl_input_history.json")

# Figures
for fig in os.listdir("figures/rl_input_space"):
    files.download(f"figures/rl_S/{fig}")
    print(f"✅ {fig}")
# Out:
# ✅ cf_optimal_eta.png
# ✅ rl_cf_examples_S.png
# ✅ cf_original_scale.png
# ✅ rl_training_curves_S.png

# %%
from google.colab import files
import os

for fig in os.listdir("figures/rl_latent_plaus/"):
    files.download(f"figures/rl_latent_plaus/{fig}")
    print(f"✅ {fig}")
# Out:
# ✅ rl_lp_cf_examples.png
# ✅ rl_lp_training_curves.png
